# %%
fronius_url = "http://192.168.178.70/"

# %%
import requests

# %%
# get battery status

url = fronius_url + "solar_api/v1/GetStorageRealtimeData.cgi"

res = requests.get(url)

# %%
res.json()['Body']['Data']['0']['Controller']
# Out:
# {'Capacity_Maximum': 13824.0,
#  'Current_DC': 2.99110452186805,
#  'DesignedCapacity': 13824.0,
#  'Details': {'Manufacturer': 'BYD',
#   'Model': 'BYD Battery-Box Premium HV',
#   'Serial': 'P030T021R2506160124     '},
#  'Enable': 1,
#  'StateOfCharge_Relative': 86.3,
#  'Status_BatteryCell': 3.0,
#  'Temperature_Cell': 18.5,
#  'TimeStamp': 1778134418,
#  'Voltage_DC': 269.8}

# %% [markdown]
# ## interesting fields in the battery response:
# * StateOfCharge_Relative
# * Voltage_DC
# * Temperature_Cell

# %% [markdown]
# # Inverter requests

# %%
url = fronius_url + "solar_api/v1/GetInverterRealtimeData.cgi"

# requests parameters - defaults
params = {
    "Scope" : "Device",
    "DeviceId" : "1"
}

# %%
# common inverter data
p  = dict({"DataCollection" : "CommonInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'DAY_ENERGY': {'Unit': 'Wh', 'Value': None},
#   'DeviceStatus': {'ErrorCode': 0,
#    'InverterState': 'Running',
#    'StatusCode': 7},
#   'FAC': {'Unit': 'Hz', 'Value': 50.020145416259766},
#   'IAC': {'Unit': 'A', 'Value': 1.0684988796710968},
#   'IDC': {'Unit': 'A', 'Value': 1.0162047147750854},
#   'IDC_2': {'Unit': 'A', 'Value': 1.304872989654541},
#   'IDC_3': {'Unit': 'A', 'Value': None},
#   'IDC_4': {'Unit': 'A', 'Value': None},
#   'PAC': {'Unit': 'W', 'Value': 248.92068481445312},
#   'SAC': {'Unit': 'VA', 'Value': 248.5129852294922},
#   'TOTAL_ENERGY': {'Unit': 'Wh', 'Value': 31756738.601666667},
#   'UAC': {'Unit': 'V', 'Value': 234.64169311523438},
#   'UDC': {'Unit': 'V', 'Value': 464.723876953125},
#   'UDC_2': {'Unit': 'V', 'Value': 410.6251525878906},
#   'UDC_3': {'Unit': 'V', 'Value': None},
#   'UDC_4': {'Unit': 'V', 'Value': None},
#   'YEAR_ENERGY': {'Unit': 'Wh', 'Value': None}}}

# %%
# 3PInverterData
p  = dict({"DataCollection" : "3PInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'IAC_L1': {'Unit': 'A', 'Value': 0.35601553320884705},
#   'IAC_L2': {'Unit': 'A', 'Value': 0.356292724609375},
#   'IAC_L3': {'Unit': 'A', 'Value': 0.35619062185287476},
#   'UAC_L1': {'Unit': 'V', 'Value': 234.51473999023438},
#   'UAC_L2': {'Unit': 'V', 'Value': 232.0308380126953},
#   'UAC_L3': {'Unit': 'V', 'Value': 231.3988037109375}}}
