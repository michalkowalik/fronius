# %%
fronius_url = "http://192.168.178.70/"

# %%
import requests

# %%
# get battery status

url = fronius_url + "solar_api/v1/GetStorageRealtimeData.cgi"

res = requests.get(url)

# %%
res.json()['Body']
# Out:
# {'Data': {'0': {'Controller': {'Capacity_Maximum': 13824.0,
#     'Current_DC': -1.8972033257747543,
#     'DesignedCapacity': 13824.0,
#     'Details': {'Manufacturer': 'BYD',
#      'Model': 'BYD Battery-Box Premium HV',
#      'Serial': 'P030T021R2506160124     '},
#     'Enable': 1,
#     'StateOfCharge_Relative': 83.8,
#     'Status_BatteryCell': 3.0,
#     'Temperature_Cell': 17.5,
#     'TimeStamp': 1777755544,
#     'Voltage_DC': 264.6},
#    'Modules': []}}}

# %% [markdown]
# ## interesting fields in the battery response:
# * StateOfCharge_Relative
# * Voltage_DC
# * Temperature_Cell

# %% [markdown]
# # Inverter requests

# %%
url = fronius_url + "solar_api/v1/GetInverterRealtimeData.cgi"

# requests parameters - defaults
params = {
    "Scope" : "Device",
    "DeviceId" : "1"
}

# %%
# common inverter data
p  = dict({"DataCollection" : "CommonInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'DAY_ENERGY': {'Unit': 'Wh', 'Value': None},
#   'DeviceStatus': {'ErrorCode': 0,
#    'InverterState': 'Running',
#    'StatusCode': 7},
#   'FAC': {'Unit': 'Hz', 'Value': 50.0213623046875},
#   'IAC': {'Unit': 'A', 'Value': 1.141533076763153},
#   'IDC': {'Unit': 'A', 'Value': 0.006169095169752836},
#   'IDC_2': {'Unit': 'A', 'Value': 0.002520757494494319},
#   'IDC_3': {'Unit': 'A', 'Value': None},
#   'IDC_4': {'Unit': 'A', 'Value': None},
#   'PAC': {'Unit': 'W', 'Value': 267.68255615234375},
#   'SAC': {'Unit': 'VA', 'Value': 266.9960021972656},
#   'TOTAL_ENERGY': {'Unit': 'Wh', 'Value': 31510249.90388889},
#   'UAC': {'Unit': 'V', 'Value': 234.2656707763672},
#   'UDC': {'Unit': 'V', 'Value': 52.501991271972656},
#   'UDC_2': {'Unit': 'V', 'Value': 61.26099395751953},
#   'UDC_3': {'Unit': 'V', 'Value': None},
#   'UDC_4': {'Unit': 'V', 'Value': None},
#   'YEAR_ENERGY': {'Unit': 'Wh', 'Value': None}}}

# %%
# 3PInverterData
p  = dict({"DataCollection" : "3PInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'IAC_L1': {'Unit': 'A', 'Value': 0.39023274183273315},
#   'IAC_L2': {'Unit': 'A', 'Value': 0.39054426550865173},
#   'IAC_L3': {'Unit': 'A', 'Value': 0.3905623257160187},
#   'UAC_L1': {'Unit': 'V', 'Value': 234.17982482910156},
#   'UAC_L2': {'Unit': 'V', 'Value': 234.33401489257812},
#   'UAC_L3': {'Unit': 'V', 'Value': 232.47152709960938}}}
