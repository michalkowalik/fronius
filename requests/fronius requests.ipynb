# %%
fronius_url = "http://192.168.178.70/"

# %%
import requests

# %%
# get battery status

url = fronius_url + "solar_api/v1/GetStorageRealtimeData.cgi"

res = requests.get(url)

# %%
res.json()['Body']['Data']['0']['Controller']
# Out:
# {'Capacity_Maximum': 13824.0,
#  'Current_DC': -1.3962264150943395,
#  'DesignedCapacity': 13824.0,
#  'Details': {'Manufacturer': 'BYD',
#   'Model': 'BYD Battery-Box Premium HV',
#   'Serial': 'P030T021R2506160124     '},
#  'Enable': 1,
#  'StateOfCharge_Relative': 95.9,
#  'Status_BatteryCell': 3.0,
#  'Temperature_Cell': 20.5,
#  'TimeStamp': 1778352424,
#  'Voltage_DC': 265.0}

# %% [markdown]
# ## interesting fields in the battery response:
# * StateOfCharge_Relative
# * Voltage_DC
# * Temperature_Cell

# %% [markdown]
# # Inverter requests

# %% [markdown]
# ## Inverter system-scoped requests

# %%
# inverter system scope:

inv_system_scope_url = fronius_url + "solar_api/v1/GetInverterRealtimeData.cgi"

# requests parameters - defaults
params = {
    "Scope" : "System"
}

res = requests.get(inv_system_scope_url)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'DAY_ENERGY': {'Unit': 'Wh', 'Values': {'1': None}},
#   'PAC': {'Unit': 'W', 'Values': {'1': 358.24920654296875}},
#   'TOTAL_ENERGY': {'Unit': 'Wh', 'Values': {'1': 31916055.195277777}},
#   'YEAR_ENERGY': {'Unit': 'Wh', 'Values': {'1': None}}}}

# %% [markdown]
# ## Inverter device-scoped requests

# %%
url = fronius_url + "solar_api/v1/GetInverterRealtimeData.cgi"

# requests parameters - defaults
params = {
    "Scope" : "Device",
    "DeviceId" : "1"
}

# %%
# common inverter data
p  = dict({"DataCollection" : "CommonInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'DAY_ENERGY': {'Unit': 'Wh', 'Value': None},
#   'DeviceStatus': {'ErrorCode': 0,
#    'InverterState': 'Running',
#    'StatusCode': 7},
#   'FAC': {'Unit': 'Hz', 'Value': 50.01511001586914},
#   'IAC': {'Unit': 'A', 'Value': 1.5170599818229675},
#   'IDC': {'Unit': 'A', 'Value': 0.02787891961634159},
#   'IDC_2': {'Unit': 'A', 'Value': 0.015185055322945118},
#   'IDC_3': {'Unit': 'A', 'Value': None},
#   'IDC_4': {'Unit': 'A', 'Value': None},
#   'PAC': {'Unit': 'W', 'Value': 355.8485412597656},
#   'SAC': {'Unit': 'VA', 'Value': 351.9808654785156},
#   'TOTAL_ENERGY': {'Unit': 'Wh', 'Value': 31915909.899722222},
#   'UAC': {'Unit': 'V', 'Value': 232.9505615234375},
#   'UDC': {'Unit': 'V', 'Value': 134.60488891601562},
#   'UDC_2': {'Unit': 'V', 'Value': 77.11163330078125},
#   'UDC_3': {'Unit': 'V', 'Value': None},
#   'UDC_4': {'Unit': 'V', 'Value': None},
#   'YEAR_ENERGY': {'Unit': 'Wh', 'Value': None}}}

# %%
# 3PInverterData
p  = dict({"DataCollection" : "3PInverterData"}, **params)

res = requests.get(url, params=p)
print(res.status_code)
# Out:
# 200

# %%
res.json()['Body']
# Out:
# {'Data': {'IAC_L1': {'Unit': 'A', 'Value': 0.5056579113006592},
#   'IAC_L2': {'Unit': 'A', 'Value': 0.5056197643280029},
#   'IAC_L3': {'Unit': 'A', 'Value': 0.5057823061943054},
#   'UAC_L1': {'Unit': 'V', 'Value': 232.86544799804688},
#   'UAC_L2': {'Unit': 'V', 'Value': 232.05490112304688},
#   'UAC_L3': {'Unit': 'V', 'Value': 231.10804748535156}}}

# %% [markdown]
# # Smart meter queries

# %% [markdown]
# ## System-scope

# %%
meter_url = fronius_url + "solar_api/v1/GetMeterRealtimeData.cgi"
res = requests.get(meter_url, params={"Scope":"System"})

print(res.status_code)
# Out:
# 200

# %%
res.json()
# Out:
# {'Body': {'Data': {'0': {'Current_AC_Phase_1': -0.489,
#     'Current_AC_Phase_2': 0.552,
#     'Current_AC_Phase_3': 0.597,
#     'Current_AC_Sum': 0.66,
#     'Details': {'Manufacturer': 'Fronius',
#      'Model': 'Smart Meter TS 65A-3',
#      'Serial': '1976960428'},
#     'Enable': 1,
#     'EnergyReactive_VArAC_Sum_Consumed': 3710563.0,
#     'EnergyReactive_VArAC_Sum_Produced': 704544.0,
#     'EnergyReal_WAC_Minus_Absolute': 1369713.0,
#     'EnergyReal_WAC_Plus_Absolute': 8247123.0,
#     'EnergyReal_WAC_Sum_Consumed': 8247123.0,
#     'EnergyReal_WAC_Sum_Produced': 1369713.0,
#     'Frequency_Phase_Average': 50.0,
#     'Meter_Location_Current': 0.0,
#     'PowerApparent_S_Phase_1': 111.8,
#     'PowerApparent_S_Phase_2': 96.1,
#     'PowerApparent_S_Phase_3': 128.1,
#     'PowerApparent_S_Sum': 337.5,
#     'PowerFactor_Phase_1': -0.952,
#     'PowerFactor_Phase_2': 0.991,
#     'PowerFactor_Phase_3': 0.044,
#     'PowerFactor_Sum': 0.022,
#     'PowerReactive_Q_Phase_1': -34.3,
#     'PowerReactive_Q_Phase_2': -12.8,
#     'PowerReactive_Q_Phase_3': -128.0,
#     'PowerReactive_Q_Sum': -176.2,
#     'PowerReal_P_Phase_1': -106.4,
#     'PowerReal_P_Phase_2': 95.3,
#     'PowerReal_P_Phase_3': 5.6,
#     'PowerReal_P_Sum': 3.8,
#     'TimeStamp': 1778354306,
#     'Visible': 1,
#     'Voltage_AC_PhaseToPhase_12': 402.4,
#     'Voltage_AC_PhaseToPhase_23': 408.1,
#     'Voltage_AC_PhaseToPhase_31': 402.5,
#     'Voltage_AC_Phase_1': 233.8,
#     'Voltage_AC_Phase_2': 233.3,
#     'Voltage_AC_Phase_3': 233.4}}},
#  'Head': {'RequestArguments': {'Scope': 'System'},
#   'Status': {'Code': 0, 'Reason': '', 'UserMessage': ''},
#   'Timestamp': '2026-05-09T19:18:26+00:00'}}

# %% [markdown]
# ## device-scoped

# %%
meter_url = fronius_url + "solar_api/v1/GetMeterRealtimeData.cgi"
res = requests.get(meter_url, params={"Scope":"Device", "DeviceId":"0"})

print(res.status_code)
# Out:
# 200

# %%
res.json()
# Out:
# {'Body': {'Data': {'Current_AC_Phase_1': -0.41,
#    'Current_AC_Phase_2': 0.59,
#    'Current_AC_Phase_3': 0.62,
#    'Current_AC_Sum': 0.8,
#    'Details': {'Manufacturer': 'Fronius',
#     'Model': 'Smart Meter TS 65A-3',
#     'Serial': '1976960428'},
#    'Enable': 1,
#    'EnergyReactive_VArAC_Sum_Consumed': 3710563.0,
#    'EnergyReactive_VArAC_Sum_Produced': 704552.0,
#    'EnergyReal_WAC_Minus_Absolute': 1369713.0,
#    'EnergyReal_WAC_Plus_Absolute': 8247124.0,
#    'EnergyReal_WAC_Sum_Consumed': 8247124.0,
#    'EnergyReal_WAC_Sum_Produced': 1369713.0,
#    'Frequency_Phase_Average': 50.0,
#    'Meter_Location_Current': 0.0,
#    'PowerApparent_S_Phase_1': 91.1,
#    'PowerApparent_S_Phase_2': 80.0,
#    'PowerApparent_S_Phase_3': 134.6,
#    'PowerApparent_S_Sum': 305.8,
#    'PowerFactor_Phase_1': -0.906,
#    'PowerFactor_Phase_2': 0.678,
#    'PowerFactor_Phase_3': 0.158,
#    'PowerFactor_Sum': -0.031,
#    'PowerReactive_Q_Phase_1': -38.6,
#    'PowerReactive_Q_Phase_2': -58.8,
#    'PowerReactive_Q_Phase_3': -133.0,
#    'PowerReactive_Q_Sum': -230.4,
#    'PowerReal_P_Phase_1': -82.5,
#    'PowerReal_P_Phase_2': 54.2,
#    'PowerReal_P_Phase_3': 21.2,
#    'PowerReal_P_Sum': -7.0,
#    'TimeStamp': 1778354455,
#    'Visible': 1,
#    'Voltage_AC_PhaseToPhase_12': 402.8,
#    'Voltage_AC_PhaseToPhase_23': 407.2,
#    'Voltage_AC_PhaseToPhase_31': 405.0,
#    'Voltage_AC_Phase_1': 233.7,
#    'Voltage_AC_Phase_2': 233.9,
#    'Voltage_AC_Phase_3': 234.0}},
#  'Head': {'RequestArguments': {'DeviceId': '0', 'Scope': 'Device'},
#   'Status': {'Code': 0, 'Reason': '', 'UserMessage': ''},
#   'Timestamp': '2026-05-09T19:20:55+00:00'}}
